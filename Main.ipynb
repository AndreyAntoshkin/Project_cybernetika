# %%
# Создание структуры проекта
import os

# Список файлов и папок для создания
project_structure = {
    'data/': ['sensors_data.csv', 'energy_data.csv', 'equipment_data.csv'],
    'notebooks/': ['01_data_generation.ipynb', '02_data_analysis.ipynb', '03_ml_models.ipynb', '04_dashboard.ipynb'],
    'src/': ['__init__.py', 'data_generator.py', 'data_processor.py', 'models.py', 'visualization.py'],
    'config/': ['settings.py'],
    'tests/': ['__init__.py', 'test_data_generator.py'],
    'reports/': ['analysis_report.md'],
    'docs/': ['README.md', 'architecture.md'],
}

# Создаем структуру
for folder, files in project_structure.items():
    os.makedirs(folder, exist_ok=True)
    print(f"📁 Создана папка: {folder}")
    
    for file in files:
        filepath = os.path.join(folder, file)
        if not os.path.exists(filepath):
            with open(filepath, 'w') as f:
                if file.endswith('.md'):
                    f.write(f"# {file}\n\nДокументация будет здесь.")
                elif file.endswith('.py'):
                    f.write(f"# {file}\n# Модуль проекта BMS Analytics\n")
            print(f"  📄 Создан файл: {file}")

print("\n✅ Структура проекта создана!")
# Out:
# 📁 Создана папка: data/
#   📄 Создан файл: sensors_data.csv
#   📄 Создан файл: energy_data.csv
#   📄 Создан файл: equipment_data.csv
# 📁 Создана папка: notebooks/
#   📄 Создан файл: 01_data_generation.ipynb
#   📄 Создан файл: 02_data_analysis.ipynb
#   📄 Создан файл: 03_ml_models.ipynb
#   📄 Создан файл: 04_dashboard.ipynb
# 📁 Создана папка: src/
#   📄 Создан файл: __init__.py
#   📄 Создан файл: data_generator.py
#   📄 Создан файл: data_processor.py
#   📄 Создан файл: models.py
#   📄 Создан файл: visualization.py
# 📁 Создана папка: config/
#   📄 Создан файл: settings.py
# 📁 Создана папка: tests/
#   📄 Создан файл: __init__.py
#   📄 Создан файл: test_data_generator.py
# 📁 Создана папка: reports/
#   📄 Создан файл: analysis_report.md
# 📁 Создана папка: docs/
#   📄 Создан файл: README.md
#   📄 Создан файл: architecture.md
#
# ✅ Структура проекта создана!

# %%
# Создаем файл .gitignore
gitignore_content = """
# Python
__pycache__/
*.py[cod]
*$py.class
*.so
.Python
build/
develop-eggs/
dist/
downloads/
eggs/
.eggs/
lib/
lib64/
parts/
sdist/
var/
wheels/
*.egg-info/
.installed.cfg
*.egg

# Jupyter Notebook
.ipynb_checkpoints

# IDE
.vscode/
.idea/
*.swp
*.swo

# Данные (кроме образцовых)
data/*.csv
# !data/sample_*.csv

# Логи
*.log

# Окружение
venv/
env/
.env
"""

with open('.gitignore', 'w') as f:
    f.write(gitignore_content)

print("✅ .gitignore создан")
# Out:
# ✅ .gitignore создан
